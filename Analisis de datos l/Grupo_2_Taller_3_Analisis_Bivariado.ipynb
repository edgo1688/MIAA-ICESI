# %% [markdown]
# <img src="img/ICESI.png">

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Taller-de-FAII,-modelos-tradicionales-de-clasificación-aplicados-a-comportamiento-crediticio" data-toc-modified-id="Taller-de-FAII,-modelos-tradicionales-de-clasificación-aplicados-a-comportamiento-crediticio-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><span>Taller lll , Análisis Exploratorio de Datos Riesgo Cardiovascular</span></a></span></li><li><span><a href="#Contexto" data-toc-modified-id="Contexto-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Contexto</a></span><ul class="toc-item"><li><span><a href="#Pregunta-SMART" data-toc-modified-id="Pregunta-SMART-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Pregunta SMART</a></li><li><a href="#Descripción-de-los-campos" data-toc-modified-id="Descripción-de-los-campos-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Descripción de los campos</a></span></li></ul></li><li><span><a href="#Análisis-exploratorio" data-toc-modified-id="Análisis-exploratorio-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Análisis exploratorio</a></span><ul class="toc-item"><li><span><a href="#Análisis-de-estructura" data-toc-modified-id="Análisis-de-estructura-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Análisis de estructura</a></span></li><li><span><a href="#Análisis-Univariado" data-toc-modified-id="Análisis-Univariado-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Análisis Univariado</a></span></li><li><span><a href="#Análisis-Bivariado" data-toc-modified-id="Análisis-Bivariado-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Análisis Bivariado</a>
# <!-- </span></li><li><span><a href="#Análisis-de-variables-continuas" data-toc-modified-id="Análisis-de-variables-continuas-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Análisis de variables continuas</a></span><ul class="toc-item"><li><span><a href="#Analisis-de-outliers" data-toc-modified-id="Analisis-de-outliers-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Analisis de outliers</a></span><ul class="toc-item"><li><span><a href="#Outliers-de-ingresos" data-toc-modified-id="Outliers-de-ingresos-3.4.1.1"><span class="toc-item-num">3.4.1.1&nbsp;&nbsp;</span>Outliers de ingresos</a></span></li><li><span><a href="#Outliers-de-deudas-y-créditos" data-toc-modified-id="Outliers-de-deudas-y-créditos-3.4.1.2"><span class="toc-item-num">3.4.1.2&nbsp;&nbsp;</span>Outliers de deudas y créditos</a></span></li></ul></li><li><span><a href="#Conclusiones-Outliers" data-toc-modified-id="Conclusiones-Outliers-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Conclusiones Outliers</a></span></li></ul></li></ul></li><li><span><a href="#Limpieza-de-datos" data-toc-modified-id="Limpieza-de-datos-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Limpieza de datos</a></span><ul class="toc-item"><li><span><a href="#Division-de-datasets" data-toc-modified-id="Division-de-datasets-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Division de datasets</a></span></li><li><span><a href="#Ingreso-bruto-menor-a-ingreso-líquido" data-toc-modified-id="Ingreso-bruto-menor-a-ingreso-líquido-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Ingreso bruto menor a ingreso líquido</a></span></li><li><span><a href="#Estandarización" data-toc-modified-id="Estandarización-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Estandarización</a></span></li><li><span><a href="#Imputación" data-toc-modified-id="Imputación-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Imputación</a></span></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Dummificar-variables" data-toc-modified-id="Dummificar-variables-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Dummificar variables</a></span></li><li><span><a href="#PCA" data-toc-modified-id="PCA-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>PCA</a></span></li><li><span><a href="#LDA" data-toc-modified-id="LDA-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>LDA</a></span></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Clustering</a> -->

# %% [markdown]
# # Análisis Exploratorio de Datos Riesgo Cardiovascular
# Estudiantes Maestría en Inteligencia Artifical - ICESI
#
# * _Edwin Gómez_
#
# * _Johan_ _Sebastian Bonilla_
#
# * _Lina María Méndez_

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# # Contexto
#
# **Análisis de Factores de Riesgo Cardiovascular en el Distrito de Aguablanca, Cali: Una Evaluación Contextualizada del Framingham Score​:**
#
# El riesgo cardiovascular es una preocupación de salud pública a nivel mundial. Herramientas como el Framingham Score han sido ampliamente utilizadas para estimar el riesgo de eventos cardiovasculares en diversas poblaciones. Sin embargo, su aplicabilidad en comunidades con características socioeconómicas y demográficas específicas, como el Distrito de Aguablanca en Cali, Colombia, requiere evaluación. Este proyecto tiene como objetivo identificar y analizar los factores de riesgo cardiovascular más significativos en esta población, comparándolos con los contemplados en el Framingham Score. **_Se realizará un análisis de variables como masa corporal, edad, género, enfermedad renal crónica y tensión arterial, considerando el contexto socioeconómico y cultural de la comunidad. Los resultados permitirán adaptar o desarrollar herramientas de evaluación de riesgo cardiovascular más precisas para poblaciones similares_**.
#
# ---
#
# **Revisión Bibliográfica**
#
# A continuación, se presentan tres artículos científicos que abordan la evaluación del riesgo cardiovascular y la aplicabilidad del Framingham Score en diferentes contextos:​
#
# **1. Evaluación del Riesgo de Enfermedad Cardiovascular: Perspectivas desde Framingham**
#
# Este artículo destaca que las funciones de riesgo de Framingham combinan información de factores como sexo, edad, presión arterial sistólica, colesterol total, colesterol HDL, tabaquismo y diabetes para estimar el riesgo de desarrollar enfermedades cardiovasculares en un período determinado, como los próximos 10 años.
#
# **2. Estado Socioeconómico, Factores de Riesgo Cardíaco y Enfermedad Cardiovascular**
#
# Este estudio revela que la hipertensión es el factor de riesgo más común en grupos de bajo nivel socioeconómico. Además, factores como antecedentes familiares de enfermedades cardiovasculares, tabaquismo e hiperlipidemia también son prevalentes en distintos grupos socioeconómicos.
#
# **3. Asociación del Ingreso Familiar con el Riesgo de Enfermedad Cardiovascular en Adultos Estadounidenses**
#
# Este artículo analiza cómo el bajo ingreso familiar, una medida del estado socioeconómico, puede estar asociado con un mayor riesgo de enfermedades cardiovasculares, destacando la importancia de considerar factores socioeconómicos en la evaluación del riesgo.
#
# **4. Sobre la presión arterial y su relación para determinar riesgo caridovascular**
#
# Este artículo pone en contexto por qué medir la presión diferencial puede ayudar a un equipo de atención médica a predecir el riesgo de padecer eventos cardíacos y vasculares, como ataques cardíacos o accidentes cerebrovasculares. Una presión diferencial superior a 60 se considera factor de riesgo para enfermedad cardíaca, especialmente en personas mayores.
#
# **_Fuentes_**
#
# 1. D'Agostino RB Sr, Pencina MJ, Massaro JM, Coady S. Cardiovascular Disease Risk Assessment: Insights from Framingham. Glob Heart. 2013 Mar;8(1):11-23. doi: 10.1016/j.gheart.2013.01.001. PMID: 23750335; PMCID: PMC3673738.
# 2. Davari M, Maracy MR, Khorasani E. Socioeconomic status, cardiac risk factors, and cardiovascular disease: A novel approach to determination of this association. ARYA Atheroscler. 2019 Nov;15(6):260-266. doi: 10.22122/arya.v15i6.1595. PMID: 32206069; PMCID: PMC7073799.
# 3. Minhas, A.M.K., Jain, V., Li, M. et al. Family income and cardiovascular disease risk in American adults. Sci Rep 13, 279 (2023). https://doi.org/10.1038/s41598-023-27474-x
# 4. https://www.mayoclinic.org/es/diseases-conditions/high-blood-pressure/expert-answers/pulse-pressure/faq-20058189

# %% [markdown]
# ---

# %% [markdown]
# # Pregunta SMART
#
# **¿Cuáles son los factores más significativos en la predicción del riesgo cardiovascular en la población del Distrito de Aguablanca, Cali, y cómo difieren estos factores de los contemplados en el Framingham Score?"​**
#
#
#
# *   ***Específica:*** Se centra en identificar los principales factores de riesgo cardiovascular en una población definida geográficamente.
# *   ***Medible:*** Los factores de riesgo, como masa corporal, edad, género, presencia de enfermedad renal crónica y niveles de tensión arterial, son cuantificables.​
#
#
# *   ***Alcanzable:*** Se dispone de datos relevantes de la población en estudio.​
# *   ***Relevante:*** La investigación busca adaptar herramientas de evaluación de riesgo cardiovascular a contextos locales específicos.​
#
#
# *   ***Temporal:*** El estudio se basa en datos recopilados en un período determinado, permitiendo análisis actuales y futuros.

# %% [markdown]
# # Descripción de los campos

# %% [markdown]
# Cada fila contiene informacion de un paciente recopilada el dia de la consulta.
#
# - Comuna: comuna a la que percenece el paciente
# - Consecutivo: id del registro medico
# - Cruce Poblacion Asignada: ...

# %% [markdown]
# # Descripción de la importancia de columna seleccionada
#
# Los términos sistólica y diastólica se refieren a las fases del ciclo cardíaco y a las mediciones de la presión arterial:
# Medir la presión diferencial puede ayudar a un equipo de atención médica a predecir el riesgo de padecer eventos cardíacos y vasculares

# %% [markdown]
# # Análisis exploratorio
#
# Empezaremos por revisar la estructura del dataset, la consistencia entre los datos y que tengan el formato adecuado.

# %%
# Se importa la data
df = pd.read_excel("data/Reporte Cronicos ESE Oriente ABRIL 2023.xlsx", sheet_name='BASE')
df.shape
# Out:
# (43191, 101)

# %% [markdown]
# Los datos cuentan con 43.191 observaciones y 101 columnas

# %%
# Revisar primeros 5 registros
df.head()
# Out:
#       COMUNA  Consecutivo  Cruce Poblacion Asignada  1900-01-02 00:00:00  \
# 0  COMUNA 15            1                       NaN                  NaN
# 1  COMUNA 13            2                       NaN                  NaN
# 2  COMUNA 13            3                       NaN                  NaN
# 3  COMUNA 15            4                       NaN                  NaN
# 4  COMUNA 13            5                       NaN                  NaN
#
#   Fecha de Inscripcion   AÑO Fecha Ultima Atención             IPS  \
# 0           1800-01-01  2014            2014-01-02  PS COMUNEROS I
# 1           1800-01-01  2014            2014-01-02      PS CALIPSO
# 2           1800-01-01  2014            2014-01-02      PS CALIPSO
# 3           1800-01-01  2014            2014-01-07      CS VALLADO
# 4           1800-01-01  2019            2019-12-05      PS CALIPSO
#
#   1_PrimerNombre 2_SegundoNombre  ... Consumo sustancias psicoactivas  \
# 0       AQUILINO            NONE  ...                              No
# 1           LUIS         EDUARDO  ...                              No
# 2        ZORAIDA        DE JESUS  ...                              No
# 3          JULIA          ALICIA  ...                              No
# 4          MARIA     DEL SOCORRO  ...                              No
#
#   Fecha proxima cita Profesional que atendera (Medico o enfermera)  \
# 0                NaT                                           NaN
# 1                NaT                                           NaN
# 2                NaT                                           NaN
# 3                NaT                                           NaN
# 4                NaT                                           NaN
#
#   Resultado Penultima Creatinina Fecha resultado penultima creatinina  \
# 0                            NaN                                  NaT
# 1                            NaN                                  NaT
# 2                            NaN                                  NaT
# 3                            NaN                                  NaT
# 4                           0.64                           2018-11-30
#
#    Resultado Penultima RAC Fecha resultado penultima RAC  \
# 0                      NaN                           NaT
# 1                      NaN                           NaT
# 2                      NaN                           NaT
# 3                      NaN                           NaT
# 4                      NaN                           NaT
#
#   Resultado Penultima RAC.1 Fecha resultado penultima RAC.1 ESTATINA
# 0                       NaN                             NaT      NaN
# 1                       NaN                             NaT      NaN
# 2                       NaN                             NaT      NaN
# 3                       NaN                             NaT      NaN
# 4                       NaN                             NaT      NaN
#
# [5 rows x 101 columns]

# %%
# Revisar ultimos 5 registros
df.tail()
# Out:
#           COMUNA  Consecutivo  Cruce Poblacion Asignada  1900-01-02 00:00:00  \
# 43186   HOSPITAL        43187                       NaN                  NaN
# 43187   HOSPITAL        43188                31301168.0                  NaN
# 43188   HOSPITAL        43189                16751387.0                  NaN
# 43189   HOSPITAL        43190                       NaN                  NaN
# 43190  COMUNA 15        43191                31603429.0                  NaN
#
#       Fecha de Inscripcion   AÑO Fecha Ultima Atención         IPS  \
# 43186  2023-04-14 00:00:00  2023            2023-04-14    HOSPITAL
# 43187  2023-04-17 00:00:00  2023            2023-04-17    HOSPITAL
# 43188  2023-04-18 00:00:00  2023            2023-04-18    HOSPITAL
# 43189  2023-04-19 00:00:00  2023            2023-04-19    HOSPITAL
# 43190  2023-04-21 00:00:00  2023            2023-04-21  CS VALLADO
#
#       1_PrimerNombre 2_SegundoNombre  ... Consumo sustancias psicoactivas  \
# 43186       JENNIFER           YINET  ...                              No
# 43187         EDILMA            NONE  ...                              No
# 43188        ALVEIRO            NONE  ...                              No
# 43189          JORGE            NONE  ...                              No
# 43190          LUCIA            NONE  ...                              No
#
#       Fecha proxima cita Profesional que atendera (Medico o enfermera)  \
# 43186         2023-05-11                                        Medico
# 43187         2023-05-17                                        Medico
# 43188         2023-05-18                                        Medico
# 43189         2023-05-19                                     Enfermera
# 43190         2023-05-24                                        Medico
#
#       Resultado Penultima Creatinina Fecha resultado penultima creatinina  \
# 43186                            NaN                                  NaT
# 43187                           0.73                           2022-03-04
# 43188                            NaN                                  NaT
# 43189                            NaN                                  NaT
# 43190                            NaN                                  NaT
#
#        Resultado Penultima RAC Fecha resultado penultima RAC  \
# 43186                      NaN                           NaT
# 43187                      NaN                           NaT
# 43188                      NaN                           NaT
# 43189                      NaN                           NaT
# 43190                      NaN                           NaT
#
#       Resultado Penultima RAC.1 Fecha resultado penultima RAC.1  \
# 43186                       NaN                             NaT
# 43187                       NaN                             NaT
# 43188                       NaN                             NaT
# 43189                       NaN                             NaT
# 43190                       NaN                             NaT
#
#                                     ESTATINA
# 43186                                    NaN
# 43187          Atorvastatina 20 mg-C10AA0502
# 43188                                    NaN
# 43189  Atorvastatina 40 mg TABLETA-C10AA0503
# 43190                                    NaN
#
# [5 rows x 101 columns]

# %% [markdown]
# Se puede observar una muestra de los primeros y ultimos datos con los que vamos a trabajar

# %%
# Buscamos valores nulos
df.isna().sum()
# Out:
# COMUNA                                 0
# Consecutivo                            0
# Cruce Poblacion Asignada           12129
# 1900-01-02 00:00:00                43182
# Fecha de Inscripcion                   0
#                                    ...
# Resultado Penultima RAC            40242
# Fecha resultado penultima RAC      40242
# Resultado Penultima RAC.1          42065
# Fecha resultado penultima RAC.1    42065
# ESTATINA                           31145
# Length: 101, dtype: int64

# %% [markdown]
# Se puede obervar que hay multiples columnas sin informacion, para algunas otras columnas contamos con valores nulos. En el proceso de limpieza se decidirá qué hacer con estas observaciones.

# %%
# listar columnas
list(df.columns)
# Out:
# ['COMUNA',
#  'Consecutivo',
#  'Cruce Poblacion Asignada',
#  datetime.datetime(1900, 1, 2, 0, 0),
#  'Fecha de Inscripcion',
#  'AÑO',
#  'Fecha Ultima Atención',
#  'IPS',
#  '1_PrimerNombre',
#  '2_SegundoNombre',
#  '3_PrimerApellido',
#  '4_SegundoApellido',
#  '5_TipoIdentificacion',
#  '6_Identificacion',
#  '7_FechaNac',
#  'EDAD (Años cumplidos)',
#  'GRUPO EDAD',
#  '8_Sexo',
#  '9_Regimen',
#  '10_EPS',
#  '11_CodEtnia',
#  '12_GrupoPob',
#  'METODO DE PLANIFICACION',
#  '13_CodMun',
#  '14_Telefono',
#  'DIRECCION',
#  '15_Escolaridad',
#  '16_CodIPSsegto',
#  'Zona',
#  '18_DxHTA',
#  'Tipo de Consulta y profesional',
#  '20_DxDM',
#  'Clasificación DM',
#  '22_EtiologiaERC',
#  '23_Peso',
#  '24_Talla',
#  'Indice Masa Corporal = Peso/talla Al Cuadrado',
#  'Clasificación IMC',
#  'Sedentario',
#  'Cigarrillo',
#  'Sobrepeso',
#  'Obesidad',
#  'Alcohol',
#  'Aliment inadecuada (sal, pocas frutas y verduras)',
#  '25_TenArtSis',
#  '26_TenArtDitlica',
#  'CLASIFICACION FINAL DEL RIESGO',
#  '27_Creatinina',
#  '27_1_FechaCrea',
#  '28_HemoGlicosilada',
#  '28_1_FechaHemoGlico',
#  '29_Albuminuria',
#  '29_1_FechaAlbnuria',
#  '30_Creatinuria',
#  '30_FechaCreatinuria',
#  '31_ColesterolTotal',
#  '31_1_FechaCT',
#  '32_HDL',
#  '32_1_FechaHDL',
#  '33_LDL',
#  '33_1_FechaLDL',
#  '35_TFG',
#  '36_RcbeIECA',
#  '37_RcbeARA2',
#  '38_DxERC',
#  '40_FechaDxERC',
#  '41_ProgramAteERC (NEFROPROTECCION)',
#  'ENDOSALUD',
#  '79_Novedad',
#  '81_FechaMuerte',
#  '80_CausaMuerte',
#  '82_Glicemia',
#  '82_1_Fecha Glicemia',
#  '83_Trigliceridos',
#  '83_1_Fecha Trigliceridos',
#  '84_Cociente albuminuria/creatinuria',
#  '84_1_Cociente albuminuria/creatinuria',
#  'Proteinas 0-15',
#  'Eritrocitos 0-18 mgd',
#  'Cilindros patologicos',
#  'Analisis Uroanalisis',
#  'Fecha Uroanalisis',
#  'Fecha Electrocardiograma',
#  'Fecha consulta medicina familiar',
#  'Fecha consulta medicina interna',
#  'Fecha consulta psicologia',
#  'Fecha consulta nutricion',
#  'Perimetro abdominal',
#  'Perimetro de cadera',
#  'Adherencia a tratamiento (Morisky green',
#  'Conocimiento de la enfermedad(Test de batalla)',
#  'Consumo sustancias psicoactivas',
#  'Fecha proxima cita',
#  'Profesional que atendera (Medico o enfermera)',
#  'Resultado Penultima Creatinina',
#  'Fecha resultado penultima creatinina',
#  'Resultado Penultima RAC',
#  'Fecha resultado penultima RAC',
#  'Resultado Penultima RAC.1',
#  'Fecha resultado penultima RAC.1',
#  'ESTATINA']

# %% [markdown]
# La columna objetivo es 'CLASIFICACION FINAL DEL RIESGO'.

# %%
# Revisar distribucion de la columna objetivo
(df.value_counts('CLASIFICACION FINAL DEL RIESGO',normalize=True)*100).round(2).astype(str)+'%'
# Out:
# CLASIFICACION FINAL DEL RIESGO
# ALTO         37.3%
# BAJO        33.07%
# MODERADO    24.72%
# MUY ALTO      4.9%
# Name: proportion, dtype: object

# %% [markdown]
# Podemos observar que la variable objetivo es multidimensional con cuatro posibles respuestas, teniendo mayor participacion la clasificacion ALTO con un 37.3% y con menor participacion MUY ALTO con 4.9%

# %%
# Graficamos la distribucion de la variable objetivo

x = sns.countplot(x='CLASIFICACION FINAL DEL RIESGO', data=df, order=df['CLASIFICACION FINAL DEL RIESGO'].value_counts().index)
total = len(df)
for p in x.patches:
    height = p.get_height()
    percentage = (height / total) * 100
    x.text(p.get_x() + p.get_width() / 2, height + 0.1, f'{percentage:.2f}%', 
            ha='center', va='bottom')

plt.title('Distribución de la variable objetivo con porcentajes')
plt.xlabel('Clasificacion del riesgo')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# # Análisis Univariado
#
# Para cada variable clave:
#
# 1. Calcularemos estadísticas descriptivas (media, mediana, desviación estándar,
#    valores mínimos y máximos).
# 2. Graficaremos su distribución con histogramas y boxplots para detectar posibles problemas.

# %%
# Seleccion de variables
features = ['25_TenArtSis','26_TenArtDitlica']

# Verificar registros con caracteres especiales dentro del formato numerico
df[features] = df[features].apply(pd.to_numeric, errors='coerce')
df_clean = df[features] .dropna(subset=features)
df_clean.describe().T
# Out:
#                     count        mean        std   min    25%    50%    75%  \
# 25_TenArtSis      43191.0  126.154060  15.406731  80.0  120.0  120.0  130.0
# 26_TenArtDitlica  43191.0   78.316015   9.082656  60.0   70.0   80.0   80.0
#
#                     max
# 25_TenArtSis      227.0
# 26_TenArtDitlica  160.0

# %%
# Generar graficas para analizar la distribución
for col in df_clean.columns:
    if col in df_clean.columns:
        fig, axes = plt.subplots(1, 3, figsize=(14, 5))

        # Histograma con KDE (curva de densidad)
        sns.histplot(df_clean[col].dropna(), bins=30, kde=True, ax=axes[0], color="royalblue")
        axes[0].set_title(f"Distribución de {col}")
        axes[0].set_xlabel(col)
        axes[0].set_ylabel("Frecuencia")

        # Boxplot para detección de outliers
        sns.boxplot(x=df_clean[col], ax=axes[1], color="orange")
        axes[1].set_title(f"Boxplot de {col}")


        # Violinplot para visualizar la densidad de los datos
        sns.violinplot(x=df_clean[col], ax=axes[2], color="green")
        axes[2].set_title(f"Violinplot de {col}")

        plt.tight_layout()
        plt.show()

# %% [markdown]
# # Análisis de los resultados
#
# 🔹 **1. Tensión Arterial Sistólica (mmHg)**
#
# **_Media:_** 124.7 mmHg (normal-alta)
#
# **_Mediana:_** 120 mmHg
#
# **_Mínimo:_** 70 mmHg (dentro de lo normal)
#
# **_Máximo: 250 mmHg_** (Posible hipertensión severa o error)
#
# **_Desviación estándar:_** 15.5 mmHg
#
# **🔹 2. Tensión Arterial Diastólica (mmHg)**
#
# **_Media:_** 77.8 mmHg (normal)
#
# **_Mediana:_** 80 mmHg
#
# **_Mínimo:_** 0 mmHg ( Error en los datos)
#
# **_Máximo:_** 152 mmHg (Posible error o hipertensión extrema)
#
# **_Desviación estándar:_** 9.67 mmHg
#
# # Conclusiones:
#
# 🔹 Datos erróneos: 1.120 / 24.071 lo que representa un 4.65% de la base total
#
# 🔹 El promedio y la mediana de la tensión arterial diastólica indican una presión normal-alta.
# Un valor de 0 mmHg es un error de medición o un dato faltante.
# 152 mmHg es muy alto, hay que verificar su validez.
#
# 🔹 La mediana de la tensión arterial sistólica de 120 mmHg es normal, pero hay datos de hipertensión en la población. El valor máximo de 250 mmHg es muy alto, lo cual podría tratarse de un error o un caso severo.

# %% [markdown]
# ---

# %% [markdown]
# **_Clasificación de la presión arterial (según la AHA - American Heart Association)_**
#
# | Categoría                | Sistólica (mmHg) | Diastólica (mmHg) |
# | ------------------------ | ---------------- | ----------------- |
# | **Normal**               | Menos de 120     | Menos de 80       |
# | **Elevada**              | 120-129          | Menos de 80       |
# | **Hipertensión Etapa 1** | 130-139          | 80-89             |
# | **Hipertensión Etapa 2** | 140 o más        | 90 o más          |
# | **Crisis Hipertensiva**  | Más de 180       | Más de 120        |

# %% [markdown]
# # Próximos pasos
#
# 🔹 Para el análisis bivariado, sería útil explorar la relación entre IMC y tensión arterial, para verificar si el sobrepeso está afectando la presión arterial en esta población.
# Realizar limpieza y tratamiento de datos atípicos ya que observamos: campos vacíos, caracteres de texto en campos numéricos (0/0, 60/, 90/, Null), valores en 0 (Indicando que la persona está sin signos vitales) y valores máximos fuera de rango

# %% [markdown]
# # Análisis Bivariado

# %% [markdown]
# Para el analisis bivariado, consideraremos en principio las metricas que de acuerdo a la litratura podrian explicar la clasificacion del riesgo cardiovascular.

# %%
columnas_de_interes = [
    'Consecutivo', 'EDAD (Años cumplidos)', '8_Sexo', '18_DxHTA', '20_DxDM',  '22_EtiologiaERC', '23_Peso', '24_Talla', 'Sedentario', 'Cigarrillo', 'Sobrepeso', 'Obesidad', 'Alcohol',
    'Aliment inadecuada (sal, pocas frutas y verduras)', '25_TenArtSis', '26_TenArtDitlica', 'CLASIFICACION FINAL DEL RIESGO','27_Creatinina',  '28_HemoGlicosilada',  
    '29_Albuminuria', '30_Creatinuria',  '31_ColesterolTotal', '32_HDL',  '33_LDL', '35_TFG', '36_RcbeIECA', '37_RcbeARA2', '38_DxERC',  '82_Glicemia', '83_Trigliceridos', 
    '83_1_Fecha Trigliceridos', '84_Cociente albuminuria/creatinuria', '84_1_Cociente albuminuria/creatinuria','Proteinas 0-15', 'Eritrocitos 0-18 mgd', 'Cilindros patologicos', 
    'Analisis Uroanalisis', 'Fecha Uroanalisis', 'Fecha Electrocardiograma', 'Fecha consulta medicina familiar', 'Fecha consulta medicina interna', 'Fecha consulta psicologia',
    'Fecha consulta nutricion', 'Perimetro abdominal', 'Perimetro de cadera', 'Adherencia a tratamiento (Morisky green','Conocimiento de la enfermedad(Test de batalla)', 
    'Consumo sustancias psicoactivas'
]

df_clean = df[columnas_de_interes]
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43191 entries, 0 to 43190
# Data columns (total 48 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Consecutivo                                        43191 non-null  int64
#  1   EDAD (Años cumplidos)                              43191 non-null  int64
#  2   8_Sexo                                             43191 non-null  object
#  3   18_DxHTA                                           43191 non-null  object
#  4   20_DxDM                                            43191 non-null  object
#  5   22_EtiologiaERC                                    43191 non-null  object
#  6   23_Peso                                            43191 non-null  float64
#  7   24_Talla                                           43191 non-null  float64
#  8   Sedentario                                         42546 non-null  object
#  9   Cigarrillo                                         41876 non-null  object
#  10  Sobrepeso                                          15761 non-null  object
#  11  Obesidad                                           15239 non-null  object
#  12  Alcohol                                            42546 non-null  object
#  13  Aliment inadecuada (sal, pocas frutas y verduras)  8 non-null      object
#  14  25_TenArtSis                                       43191 non-null  int64
#  15  26_TenArtDitlica                                   43191 non-null  int64
#  16  CLASIFICACION FINAL DEL RIESGO                     43191 non-null  object
#  17  27_Creatinina                                      42158 non-null  float64
#  18  28_HemoGlicosilada                                 15423 non-null  float64
#  19  29_Albuminuria                                     35033 non-null  float64
#  20  30_Creatinuria                                     31589 non-null  object
#  21  31_ColesterolTotal                                 39770 non-null  float64
#  22  32_HDL                                             39701 non-null  float64
#  23  33_LDL                                             39399 non-null  float64
#  24  35_TFG                                             42158 non-null  float64
#  25  36_RcbeIECA                                        43191 non-null  object
#  26  37_RcbeARA2                                        43191 non-null  object
#  27  38_DxERC                                           0 non-null      float64
#  28  82_Glicemia                                        36316 non-null  float64
#  29  83_Trigliceridos                                   36119 non-null  object
#  30  83_1_Fecha Trigliceridos                           36119 non-null  datetime64[ns]
#  31  84_Cociente albuminuria/creatinuria                22146 non-null  float64
#  32  84_1_Cociente albuminuria/creatinuria              22146 non-null  datetime64[ns]
#  33  Proteinas 0-15                                     35638 non-null  object
#  34  Eritrocitos 0-18 mgd                               35638 non-null  object
#  35  Cilindros patologicos                              35638 non-null  object
#  36  Analisis Uroanalisis                               35638 non-null  object
#  37  Fecha Uroanalisis                                  35638 non-null  datetime64[ns]
#  38  Fecha Electrocardiograma                           35946 non-null  object
#  39  Fecha consulta medicina familiar                   18450 non-null  datetime64[ns]
#  40  Fecha consulta medicina interna                    19692 non-null  datetime64[ns]
#  41  Fecha consulta psicologia                          22929 non-null  datetime64[ns]
#  42  Fecha consulta nutricion                           12988 non-null  datetime64[ns]
#  43  Perimetro abdominal                                43191 non-null  int64
#  44  Perimetro de cadera                                43191 non-null  int64
#  45  Adherencia a tratamiento (Morisky green            43191 non-null  object
#  46  Conocimiento de la enfermedad(Test de batalla)     43191 non-null  object
#  47  Consumo sustancias psicoactivas                    43191 non-null  object
# dtypes: datetime64[ns](7), float64(12), int64(6), object(23)
# memory usage: 15.8+ MB

# %% [markdown]
# Análisis bivariado por variables numericas vs variable objtivo

# %%
# Boxplot de la variable 'EDAD (Años cumplidos)' por 'CLASIFICACION FINAL DEL RIESGO'
plt.figure(figsize=(10,6))
sns.boxplot(x='CLASIFICACION FINAL DEL RIESGO', y='EDAD (Años cumplidos)', data=df)
plt.title('Distribución de la EDAD por Clasificación de Riesgo Cardiovascular')
plt.xlabel('Clasificación Riesgo Cardiovascular')
plt.ylabel('EDAD (Años cumplidos)')
plt.show()

# Boxplot de la variable 'Peso' por 'CLASIFICACION FINAL DEL RIESGO'
plt.figure(figsize=(10,6))
sns.boxplot(x='CLASIFICACION FINAL DEL RIESGO', y='23_Peso', data=df)
plt.title('Distribución del Peso por Clasificación de Riesgo Cardiovascular')
plt.xlabel('Clasificación Riesgo Cardiovascular')
plt.ylabel('Peso')
plt.show()

# %% [markdown]
# Análisis bivariado por variables categoricas vs variable objtivo

# %%
# Graficar la distribución de 'Sexo' por 'CLASIFICACION FINAL DEL RIESGO'
plt.figure(figsize=(10,6))
sns.countplot(x='CLASIFICACION FINAL DEL RIESGO', hue='8_Sexo', data=df)
plt.title('Distribución del Sexo por Clasificación de Riesgo Cardiovascular')
plt.xlabel('Clasificación Riesgo Cardiovascular')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Seleccionar solo las columnas numéricas
df_num = df_clean.select_dtypes(include=['int64', 'float64'])

# Calcular la matriz de correlación
correlation_matrix = df_num.corr()

# Visualizar la matriz de correlación usando un heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriz de Correlación de las Variables Numéricas')
plt.show()

# %%
# Codificar la variable objetivo ('CLASIFICACION FINAL DEL RIESGO') como valores numéricos
risk_mapping = {'MUY BAJO': 0, 'MODERADO': 1, 'ALTO': 2, 'MUY ALTO': 3}
df_clean['Risk_Level'] = df_clean['CLASIFICACION FINAL DEL RIESGO'].map(risk_mapping)

# Calcular la correlación entre 'Risk_Level' y las variables numéricas
correlation_with_risk = df_num.corrwith(df_clean['Risk_Level'])

# Mostrar la correlación con la variable objetivo
print(correlation_with_risk)
# Out:
# Consecutivo                           -0.059468
# EDAD (Años cumplidos)                  0.002720
# 23_Peso                               -0.002277
# 24_Talla                              -0.010885
# 25_TenArtSis                          -0.040768
# 26_TenArtDitlica                      -0.055903
# 27_Creatinina                          0.020572
# 28_HemoGlicosilada                     0.209199
# 29_Albuminuria                         0.074522
# 31_ColesterolTotal                    -0.061457
# 32_HDL                                -0.091970
# 33_LDL                                -0.053592
# 35_TFG                                 0.037264
# 38_DxERC                                    NaN
# 82_Glicemia                            0.305183
# 84_Cociente albuminuria/creatinuria    0.089710
# Perimetro abdominal                    0.067087
# Perimetro de cadera                    0.024933
# dtype: float64
